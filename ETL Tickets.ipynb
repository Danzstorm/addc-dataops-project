# %% [markdown]
# ## Importar bibliotecas a usar

# %%
import pandas as pd
import numpy as np
import datetime as dt

# %% [markdown]
# ## Lectura del archivo "dataset.csv"

# %%
df = pd.read_csv("./dataset.csv", sep=";", dtype=str)

df.head()
# Out:
#      Numero Ticket ItemID                  Item Fecha Creacion Fecha Termino  \
# 0  WO0000005201555    121    INODORO FLUXOMETRO     2024-05-04      06-05-24
# 1  WO0000005201903    108    FOCO FLOURESCENTES     2024-05-04      05-05-24
# 2  WO0000005200489     93  ESCRITORIO CERRADURA     2024-05-04      07-05-24
# 3  WO0000005201584    256   URINARIO FLUXOMETRO     2024-05-04      04-05-24
# 4  WO0000005201907    106        FOCO AHORRADOR     2024-05-04      05-05-24
#
#   Service Desk Fecha Cierre    Resumen             Ubicacion Modo Reporte  \
# 0     Zona Sur   09/05/2024    REVISAR   LA FONTANA - 193054       Web HD
# 1   Zona Norte   08/05/2024    CAMBIAR     DIAGONAL - 285003       Web HD
# 2  Zona Centro   10/05/2024  APERTURAR  TUPAC AMARU - 191038       Web HD
# 3  Zona Centro   07/05/2024    REVISAR     UNIPLAZA - 191019       Web HD
# 4   Zona Norte   08/05/2024    CAMBIAR     DIAGONAL - 285003       Web HD
#
#     Estado Prioridad
# 0  Cerrado         3
# 1  Cerrado         3
# 2  Cerrado         3
# 3  Cerrado         3
# 4  Cerrado         3

# %% [markdown]
# ## Limpieza de datos

# %%
df = df.fillna("")

df["ItemID"] = pd.to_numeric(df['ItemID'].str.strip()).astype("Int64")
df["Fecha Creacion"] = pd.to_datetime(df["Fecha Creacion"], format='%Y-%m-%d')
df["Fecha Termino"] = pd.to_datetime(df["Fecha Termino"], format='%d-%m-%y')
df["Fecha Cierre"] = pd.to_datetime(df["Fecha Cierre"], format='%d/%m/%Y')
df["Prioridad"] = df["Prioridad"].astype(int)

# %%
df.head()
# Out:
#      Numero Ticket  ItemID                  Item Fecha Creacion Fecha Termino  \
# 0  WO0000005201555     121    INODORO FLUXOMETRO     2024-05-04    2024-05-06
# 1  WO0000005201903     108    FOCO FLOURESCENTES     2024-05-04    2024-05-05
# 2  WO0000005200489      93  ESCRITORIO CERRADURA     2024-05-04    2024-05-07
# 3  WO0000005201584     256   URINARIO FLUXOMETRO     2024-05-04    2024-05-04
# 4  WO0000005201907     106        FOCO AHORRADOR     2024-05-04    2024-05-05
#
#   Service Desk Fecha Cierre    Resumen             Ubicacion Modo Reporte  \
# 0     Zona Sur   2024-05-09    REVISAR   LA FONTANA - 193054       Web HD
# 1   Zona Norte   2024-05-08    CAMBIAR     DIAGONAL - 285003       Web HD
# 2  Zona Centro   2024-05-10  APERTURAR  TUPAC AMARU - 191038       Web HD
# 3  Zona Centro   2024-05-07    REVISAR     UNIPLAZA - 191019       Web HD
# 4   Zona Norte   2024-05-08    CAMBIAR     DIAGONAL - 285003       Web HD
#
#     Estado  Prioridad
# 0  Cerrado          3
# 1  Cerrado          3
# 2  Cerrado          3
# 3  Cerrado          3
# 4  Cerrado          3

# %% [markdown]
# ## Transformación de datos

# %%
df["Fecha Cierre"] = np.where(df["Fecha Termino"] <= df["Fecha Cierre"], df["Fecha Termino"], df["Fecha Cierre"])

df[['Agencia', 'AgenciaID']] = df['Ubicacion'].str.split('-', expand=True)
df["AgenciaID"] = df["AgenciaID"].str.strip().astype(int)
df["Agencia"] = df["Agencia"].str.strip()

# %%
df.head()
# Out:
#      Numero Ticket  ItemID                  Item Fecha Creacion Fecha Termino  \
# 0  WO0000005201555     121    INODORO FLUXOMETRO     2024-05-04    2024-05-06
# 1  WO0000005201903     108    FOCO FLOURESCENTES     2024-05-04    2024-05-05
# 2  WO0000005200489      93  ESCRITORIO CERRADURA     2024-05-04    2024-05-07
# 3  WO0000005201584     256   URINARIO FLUXOMETRO     2024-05-04    2024-05-04
# 4  WO0000005201907     106        FOCO AHORRADOR     2024-05-04    2024-05-05
#
#   Service Desk Fecha Cierre    Resumen             Ubicacion Modo Reporte  \
# 0     Zona Sur   2024-05-06    REVISAR   LA FONTANA - 193054       Web HD
# 1   Zona Norte   2024-05-05    CAMBIAR     DIAGONAL - 285003       Web HD
# 2  Zona Centro   2024-05-07  APERTURAR  TUPAC AMARU - 191038       Web HD
# 3  Zona Centro   2024-05-04    REVISAR     UNIPLAZA - 191019       Web HD
# 4   Zona Norte   2024-05-05    CAMBIAR     DIAGONAL - 285003       Web HD
#
#     Estado  Prioridad      Agencia  AgenciaID
# 0  Cerrado          3   LA FONTANA     193054
# 1  Cerrado          3     DIAGONAL     285003
# 2  Cerrado          3  TUPAC AMARU     191038
# 3  Cerrado          3     UNIPLAZA     191019
# 4  Cerrado          3     DIAGONAL     285003

# %%
data = df[["Numero Ticket", "AgenciaID", "Agencia", "Service Desk", "Fecha Creacion", "Fecha Cierre", "Estado", "ItemID", "Item"]]
data.columns = ["numero_ticket", "agencia_id", "agencia", "service_desk", "fecha_creacion", "fecha_cierre", "estad", "item_id", "item"]
